# %% [markdown]
# #Introduction:
# Toronto has long been a magnet for immigrants from all over the world. It is one of Canada's most diverse cities and prides itself on its multiculturalism.
# Census from 2011 to 2016 shows that Toronto had a total of 356,930	immigrants. Its immigrant residents represented 46.1% of the total population.
#
# Most of Canada's immigration comes from:
#
# India	307,275
# China	266,840
# Philippines	192,265
# Pakistan	119,085
# Italy.
#
#
# This project would help to determine if it would be competitive to open a Mexican restaurant in comparison to others and the actual competition in the city and near areas, also would help to identify which places could be potential for opening new restaurants.
#
# #Problem:
#
# 1.- List and visualize all major parts of Toronto and near areas that has Mexican restaurants.
#
# 2.- what is best location in Toronto and near areas for Mexican restaurants?
#
# 3.- which areas lack Mexican Restaurants?
#
#
# #Data
# There are many restaurants in Toronto segmented in by cultures and categorized by Mexican, Chinese, Indian, Brazilian, Korean, Italian, etc.
# For this project we need the following data:
# Toronto data that contains list boundaries along with their
# latitude and longitude.
#
# Data source : https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
#
# Mexican restaurants in each area of Toronto.
#
# Data source : Foursquare API
#
# Description: By using this API we will get all the venues in each area. We
# can filter these venues to get only Mexican restaurants.
#
# #Methodology:
# We begin by collecting the Toronto data from the data set we presented before.
#
# We will find all venues for each neighbourhood using Foursquare API
#
# ![Captura de Pantalla 2020-08-13 a la(s) 15.38.15.png](data:image/png;base64,...)
#
# We will then filter out all venues with Mexican restaurant for further analysis.
#
# ![Captura de Pantalla 2020-08-13 a la(s) 15.45.30.png](data:image/png;base64,...)
#
# #Results
# Creating the clusters we can find in which areas are Mexican restaurants
#
# ![Captura de Pantalla 2020-08-13 a la(s) 15.48.30.png](data:image/png;base64,...)
#
# ![Captura de Pantalla 2020-08-13 a la(s) 15.49.37.png](data:image/png;base64,...)
#
# #Discussion
#
# Most of the Mexican restaurants are in cluster 1 which is around
#
# Kensington Market, Chinatown, Grange Park, High Park, The Junction South.
#
# And lowest in Cluster 0 areas which are in Garden District, Ryerson.
#
# #Conclusion
#
# In conclusion there are opportunities for oppening a Mexican restaurant near the areas of the cluster 1 and 2, considering competition i think the best option are the areas of the cluster 2 because there are less restaurants than in cluster 1 and in cluster 0 there are only 1 restaurant but that doesn't mean that is better because there wouldn't be much competition. that could mean that there are not much customers and is not a competititve place.
